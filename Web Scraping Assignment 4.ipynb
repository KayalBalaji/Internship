# %%
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import requests
import re
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.

# %%
driver=webdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
Rank = []
Name = []
Artist= []
Upload_Date = []
Views = []


# Scraping rank
r_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//td[1]')
for i in r_tags[0:30]:
    rk=i.text
    Rank.append(rk)
    

# Scraping Name
n_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//td[2]')
for i in n_tags[0:30]:
    nm=i.text
    Name.append(nm)
    
    
# Scraping Artist
a_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//td[3]')
for i in a_tags[0:30]:
    at=i.text
    Artist.append(at)
    

# Scraping Upload_Date
u_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//td[5]')
for i in u_tags[0:30]:
    ue=i.text
    Upload_Date.append(ue)
    
    
# Scraping Views
v_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//td[4]')
for i in v_tags[0:30]:
    vs=i.text
    Views.append(vs)

# %%
df=pd.DataFrame({'Rank':Rank, 'Name':Name, 'Artist':Artist, 'Upload_Date':Upload_Date, 'Views':Views})
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                                  "Bath Song"[15]
# 5    6.                              "See You Again"[16]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.                              "Gangnam Style"[24]
# 10  11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %%
driver.close()

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.

# %%
driver=webdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.bcci.tv/")

# %%
#clickin on International tab
International = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
International.click()

# %%
Title = []
Series = []
Place = []
Date = []
Time = []

# Scraping title
t_tags=driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
for i in t_tags[0:30]:
    ti=i.text
    Title.append(ti)


# Scraping Series
S_tags=driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
for i in S_tags[0:30]:
    ss=i.text.replace('-',"")
    Series.append(ss)

    
# Scraping Place
P_tags=driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')
for i in P_tags[0:30]:
    pl=i.text
    Place.append(pl)
    
    
# Scraping Date
D_tags=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
for i in D_tags[0:2]:
    dt=i.text
    Date.append(dt)


# Scraping Time
T_tags=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
for i in T_tags[0:2]:
    ti=i.text
    Time.append(ti)

# %%
df=pd.DataFrame({'Match Title':Title, 'Series':Series, 'Place':Place, 'Date':Date, 'Time':Time})
df
# Out:
#                    Match Title     Series                      Place  \
# 0  ICC MENS T20 WORLD CUP 2022  4th T20I              Adelaide Oval,
# 1  ICC MENS T20 WORLD CUP 2022  5th T20I   Melbourne Cricket Ground,
#
#          Date         Time
# 0  2 NOV 2022  1:30 PM IST
# 1  6 NOV 2022  1:30 PM IST

# %%
driver.close()

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.

# %%
driver=webdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.guru99.com/")

# %%
#clickin on Selenium
selenium = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a')
selenium.click()

# %%
#clickin on Selenium Exception Handling
Exception = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a')
Exception.click()

# %%
exp_name=[i.text.split(':') for i in driver.find_elements(By.XPATH,"//div[@class='entry-content single-content']/p")][:40]

# %%
df=pd.DataFrame({'Exception Details':exp_name})
df
# Out:
#                                     Exception Details
# 0   [1. ElementNotVisibleException,  This type of ...
# 1   [2. ElementNotSelectableException,  This Selen...
# 2   [3. NoSuchElementException,  This Exception oc...
# 3   [4. NoSuchFrameException,  This Exception occu...
# 4   [5. NoAlertPresentException,  This Exception o...
# 5   [6. NoSuchWindowException,  This Exception occ...
# 6   [7. StaleElementReferenceException,  This Sele...
# 7   [8. SessionNotFoundException,  The WebDriver i...
# 8   [9. TimeoutException,  Thrown when there is no...
# 9   [10. WebDriverException,  This Exception takes...
# 10  [11. ConnectionClosedException,  This type of ...
# 11  [12. ElementClickInterceptedException,  The co...
# 12  [13. ElementNotInteractableException,  This Se...
# 13  [14. ErrorInResponseException,  This happens w...
# 14  [15. ErrorHandler.UnknownServerException,  Exc...
# 15  [16. ImeActivationFailedException,  This expec...
# ...

# %%
driver.close()

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.

# %%
driver=webdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("http://statisticstimes.com/")

# %%
#clickin on Economy

driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/button").click()

# %%
# Clicking on India

driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]").click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="47d59e86a49c87b741e36e73e84b91e0", element="bd08cb1d-3abd-4519-ba3d-1aee0af28cd7")>>

# %%
# Clicking on GDP of Indian Economy
GDP = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()
time.sleep(3)

# %%
RANK = []
State = []
GSDP = []
Share = []
GDP_billion = []

# Scraping Rank
rn_tags=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[1]")
for i in rn_tags[0:33]:
    rk=i.text
    RANK.append(rk)
    

# Scraping State
ST_tags=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[2]")
for i in ST_tags[0:33]:
    st=i.text
    State.append(st)

    
# Scraping GSDP(18-19)
G_tags=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[4]")
for i in G_tags[0:33]:
    gs=i.text
    GSDP.append(gs)

    
# Scraping Share
E_tags=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[5]")
for i in E_tags[0:33]:
    ar=i.text
    Share.append(ar)

    
# Scraping GDP_billion
Gb_tags=driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[6]")
for i in Gb_tags[0:33]:
    ll=i.text
    GDP_billion.append(ll)

# %%
df=pd.DataFrame({'Rank':RANK, 'State':State, 'GSDP(18-19)':GSDP, 'Share(18-19)':Share, 'GDP($ billion)':GDP_billion})
df
# Out:
#    Rank                      State GSDP(18-19) Share(18-19) GDP($ billion)
# 0     1                Maharashtra   2,632,792       13.94%        399.921
# 1     2                 Tamil Nadu   1,630,208        8.63%        247.629
# 2     3              Uttar Pradesh   1,584,764        8.39%        240.726
# 3     4                    Gujarat   1,502,899        7.96%        228.290
# 4     5                  Karnataka   1,493,127        7.91%        226.806
# 5     6                West Bengal   1,089,898        5.77%        165.556
# 6     7                  Rajasthan     942,586        4.99%        143.179
# 7     8             Andhra Pradesh     862,957        4.57%        131.083
# 8     9                  Telangana     861,031        4.56%        130.791
# 9    10             Madhya Pradesh     809,592        4.29%        122.977
# 10   11                     Kerala     781,653        4.14%        118.733
# ...

# %% [markdown]
# GSDP(17-18) details is not available in website.

# %%
driver.close()

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.

# %%
driver=webdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://github.com/")

# %%
# Click on explore

explore = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]')
explore.click()

# %%
# Click on Trending

trending = driver.find_element(By.XPATH,'//*[@href="/trending"]')
try:
    driver.get(trending.get_attribute('href'))
except ElementNotInteractableException:
    driver.get(trending.get_attribute('href'))

# %%
Repository_title = []
Descriptions = []
Contributors = []
Language = []

# %%
# Scraping Repository Title
RT_tags=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
for i in RT_tags[0:25]:
    ret=i.text
    Repository_title.append(ret)

# %%
Repository_title
# Out:
# ['geohot / tinygrad',
#  'stashapp / stash',
#  'refinedev / refine',
#  'Sanster / lama-cleaner',
#  'alibaba / havenask',
#  'SheerSt / pokewilds',
#  'microsoft / PowerToys',
#  'jwasham / coding-interview-university',
#  'Bdenneu / CVE-2022-33679',
#  'sottlmarek / DevSecOps',
#  'rodrigorgtic / nlwcopa-mobile-components',
#  'prowler-cloud / prowler',
#  'milanm / DevOps-Roadmap',
#  'grafana / grafana',
#  'ssnhd / googlevoice',
#  'prometheus / prometheus',
#  'commaai / openpilot',
#  'NationalSecurityAgency / ghidra',
#  'pointfreeco / swift-composable-architecture',
#  'tiangolo / fastapi',
#  'Netflix / conductor',
#  'Wechat-ggGitHub / Awesome-GitHub-Repo',
#  'surrealdb / surrealdb',
#  'unifyai / ivy',
#  'danielgindi / Charts']

# %%
# Scraping Description
DON_tags=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in DON_tags[0:25]:
    dis=i.text
    Descriptions.append(dis)

# %%
len(Descriptions)
# Out:
# 24

# %%
# Scraping Language
LAN_tags=driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]//span[1]')
for i in LAN_tags[0:25]:
    ln=i.text
    try:
        Language.append(ln)
    except NoSuchElementException:
        Language.append('-')

# %%
len(Language)
# Out:
# 25

# %%
# Scraping Contributors
CN_tags=driver.find_elements(By.XPATH,'//a[@class="Link--muted d-inline-block mr-3"]')
for i in CN_tags[0:50]:
    con=i.text
    Contributors.append(con)

# %%
Contrib=[]
Contrib=Contributors[1:50:2]

# %%
len(Contrib)
# Out:
# 25

# %%
df=pd.DataFrame({'Repository Title':Repository_title[0:24], 'Repository Description':Descriptions, 'Languages Used':Language[0:24], 'Contributors Count':Contrib[0:24]})
df
# Out:
#                                Repository Title  \
# 0                             geohot / tinygrad
# 1                              stashapp / stash
# 2                            refinedev / refine
# 3                        Sanster / lama-cleaner
# 4                            alibaba / havenask
# 5                           SheerSt / pokewilds
# 6                         microsoft / PowerToys
# 7         jwasham / coding-interview-university
# 8                      Bdenneu / CVE-2022-33679
# 9                        sottlmarek / DevSecOps
# 10     rodrigorgtic / nlwcopa-mobile-components
# 11                      prowler-cloud / prowler
# 12                      milanm / DevOps-Roadmap
# 13                            grafana / grafana
# 14                          ssnhd / googlevoice
# 15                      prometheus / prometheus
# 16                          commaai / openpilot
# 17              NationalSecurityAgency / ghidra
# ...

# %%
driver.close()

# %% [markdown]
# 6. Scrape the details of top 100 songs on billiboard.com.

# %%
driver=w2ebdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https:/www.billboard.com/")

# %%
#Clicking on charts
Charts=driver.find_element(By.XPATH,'/html/body/div[3]/div[7]/div/div/div/ul/li[1]/h3/a')
Charts.click()

# %%
Song_Name = []
Artist_Name = []
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# %%
# Scraping name
for i in driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]'):
    Song_Name.append(i.text)

# %%
len(Song_Name)
# Out:
# 100

# %%
#Scrappin Artist name 1 st one
Artist_Name.append(driver.find_element(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet']").text)
#Remainig Artist Name
artistTag=driver.find_elements(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
Artist_Name.extend([i.text for i in artistTag])
#Scapping Rank
rank=[]
rankTag=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet']")
rank.extend([i.text for i in rankTag[:3]])
#Remaining RAnk
Rank=[]
RankTag=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
Rank.extend([i.text for i in RankTag])

# %%
# removing ''
for i in Rank:
    if i=='':
        Rank.remove(i)

# %%
# slicing as per requirement
lastweekpos=Rank[0::3]
lastweekpos.insert(0,rank[0])
peakPos=Rank[1::3]
peakPos.insert(0,rank[1])
weeksonBoard=Rank[2::3]
weeksonBoard.insert(0,rank[2])

# %%
len(Song_Name),len(Artist_Name),len(lastweekpos),len(peakPos),len(weeksonBoard)
# Out:
# (100, 100, 133, 133, 133)

# %%
df=pd.DataFrame({'Song Name':Song_Name, 'Artist Name':Artist_Name, 'Last week rank':lastweekpos[0:100], 'Peak rank':peakPos[0:100], 'Weeks on board':weeksonBoard[0:100]})
df
# Out:
#                                             Song Name  \
# 0             Unholy\nSam Smith & Kim Petras\n2\n1\n4
# 1                     Bad Habit\nSteve Lacy\n1\n1\n16
# 2                   As It Was\nHarry Styles\n3\n1\n29
# 3                California Breeze\nLil Baby\n-\n4\n1
# 4   I Like You (A Happier Song)\nPost Malone Featu...
# ..                                                ...
# 95                      Static\nSteve Lacy\n84\n78\n7
# 96  Bzrp Music Sessions, Vol. 52\nBizarrap & Queve...
# 97                         Soul\nLee Brice\n85\n83\n6
# 98                Forget Me\nLewis Capaldi\n95\n95\n3
# 99           Good Love\nCity Girls & Usher\n86\n70\n5
#
#                        Artist Name Last week rank Peak rank Weeks on board
# 0           Sam Smith & Kim Petras              2         1              4
# 1                       Steve Lacy              1         1             16
# 2                     Harry Styles              3         1             29
# ...

# %%
driver.close()

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.

# %%
driver=webdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/hr-recruiters-consultants")

# %%
designation=driver.find_element(By.XPATH, '//input[@class="sugInp"]')
designation.send_keys('Data Science')

# %%
search=driver.find_element(By.XPATH, '//button[@class="fl qsbSrch blueBtn"]')
search.click()

# %%
NAME=[]

for page in range(0,10):
    name=driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
    for i in name:
        NAME.append(i.text)
    nxt_button=driver.find_element(By.XPATH,'//button[@class="grayBtn"]')
    nxt_button.click()
    time.sleep(2)

# %%
NAME
# Out:
# ['Aakash Harit',
#  'shravan Kumar Gaddam',
#  'MARSIAN Technologies LLP',
#  'Anik Agrawal',
#  'subhas patel',
#  'Abhishek - Only Analytics Hiring - India and',
#  'Institute for Financial Management and Resear',
#  'Balu Ramesh',
#  'Asif Lucknowi',
#  'InstaFinancials',
#  'Kalpana Dumpala',
#  'Mubarak',
#  'Kushal Rastogi',
#  'Mahesh Babu Channa',
#  'Vaishnavi Kudalkar',
#  'Priyanka Akiri',
#  'Kapil Devang',
#  'Sakshi Chhikara',
#  'Ruchi Dhote',
#  'Manisha Yadav',
#  'Riya Rajesh',
#  'Rashmi Bhattacharjee',
#  'Faizan Kareem',
#  'Rithika dadwal',
#  'Sandhya Khandagale',
#  'Shaun Rao',
#  'Azahar Shaikh',
#  'Manas',
#  'kumar',
#  'Sunil Vedula',
#  'Rajat Kumar',
#  'Dhruv Dev Dubey',
#  'Jayanth N',
#  'Avodha',
#  'Priya Khare',
#  'Amit Sharma',
#  'Kanan',
#  'Shashikant Chaudhary',
#  'Brad',
#  'Rutuja Pawar',
#  'Madhusudhan Sridhar',
#  'Ankit Sinha',
#  'Gaurav Chouhan',
#  'Rashi Kacker',
#  'Ashwini',
#  'Balaji Kolli',
#  'Rajani Nagaraj',
# ...

# %%
Designation=[]
Company=[]
Skills=[]
Location=[]
    

for page in range(0,10):
    sk=driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
    for i in sk:
        Skills.append(i.text)
    nxt_button=driver.find_element(By.XPATH,'//button[@class="grayBtn"]')
    nxt_button.click()
    time.sleep(2)
    
    
for page in range(0,10):
    loc=driver.find_elements(By.XPATH,'//small[@class="ellipsis"]')
    for i in loc:
        Location.append(i.text)
    nxt_button=driver.find_element(By.XPATH,'//button[@class="grayBtn"]')
    nxt_button.click()
    time.sleep(2)

# %%
for page in range(0,10):
    Des=driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
    for i in Des:
        Designation.append(i.text)
    nxt_button=driver.find_element(By.XPATH,'//button[@class="grayBtn"]')
    nxt_button.click()
    time.sleep(2)

# %%
#Scraping data of company name
for page in range(0,10):
    com=driver.find_elements(By.XPATH,'//p[@class="highlightable"]/a[2]')
    for i in com:
        Company.append(i.text)
    nxt_button=driver.find_element(By.XPATH,'//button[@class="grayBtn"]')
    nxt_button.click()
    time.sleep(2)

# %%
df=pd.DataFrame({'Name':NAME[0:475], 'Designation':Designation[0:475], 'Company Name': Company[0:475], 'Skills Required': Skills[0:475], 'Location':Location[0:475]})
df
# Out:
#                          Name                         Designation  \
# 0                Aakash Harit                          HR Manager
# 1        shravan Kumar Gaddam                   Company Recruiter
# 2    MARSIAN Technologies LLP                          Company HR
# 3                Anik Agrawal                   Company Recruiter
# 4                subhas patel                         Founder CEO
# ..                        ...                                 ...
# 470                Arunim Das  Co-Founder &amp; Managing Director
# 471                    Kogila                             Manager
# 472            Gurpreet Khera                     Country Manager
# 473                  Mr.Phani                             Manager
# 474              Rajpal Tyagi                   Managing Director
#
#                                 Company Name  \
# 0                       Data Science Network
# 1              Shore Infotech India Pvt. Ltd
# ...

# %%
driver.close()

# %% [markdown]
# 8. Scrape the details of Highest selling novels.

# %%
driver=webdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
#Creating empty list
Bookname = []
Authorname = []
Volumessold = []
Publisher = []
Genre = []


#scraping book names data
Bn_tags=driver.find_elements(By.XPATH,"//tbody//tr/td[2]")
for i in Bn_tags[0:100]:
    bN=i.text
    Bookname.append(bN)
    
#Scraping author names
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Authorname.append(i.text)
    except NoSuchElementException:
        Authorname.append('-')
time.sleep(1)

#Scraping data of volumes sold
ss_tags=driver.find_elements(By.XPATH,"//tbody/tr/td[4]")
for i in ss_tags[0:100]:
    SO=i.text
    Volumessold.append(SO)
    
#Scraping data of publisher names
PN_tags=driver.find_elements(By.XPATH,"//tbody/tr/td[5]")
for i in PN_tags[0:100]:
    pu=i.text
    Publisher.append(pu)
    
#Scraping data of genre
GE_tags=driver.find_elements(By.XPATH,"//tbody/tr/td[6]")
for i in GE_tags[0:100]:
    ge=i.text
    Genre.append(ge)

# %%
df=pd.DataFrame({'Title':Bookname, 'Author':Authorname, 'Volume Sales':Volumessold, 'Publisher':Publisher, 'Genre':Genre})
df
# Out:
#                                                 Title            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume Sales        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.

# %%
driver=webdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
NaMe=[]
Year_Span=[]
Genre=[]
Run_time=[]
Ratings=[][]
Votes=[]

# %%
# Scraping Name
a_tags=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')
for i in a_tags[0:100]:
    A=i.text
    NaMe.append(A)
    
    
# Scraping Year Span
y_tags=driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
for i in y_tags[0:100]:
    Y=i.text
    Year_Span.append(Y)

    
# Scraping Genre
G_tags=driver.find_elements(By.XPATH,'//span[@class="genre"]')
for i in G_tags[0:100]:
    Ge=i.text
    Genre.append(Ge)

    
# Scraping Run_time
r_tags=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
for i in r_tags[0:100]:
    R=i.text
    Run_time.append(R)

    
# Scraping Ratings
rs_tags=driver.find_elements(By.XPATH,'//span[@class="ipl-rating-star__rating"]')
for i in rs_tags[0:100]:
    RS=i.text
    Ratings.append(RS)

    
# Scraping Votes
vo_tags=driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]")
for i in vo_tags[0:100]:
    V=i.text
    Votes.append(V)

# %%
len(Name)
# Out:
# 230

# %%
df=pd.DataFrame({'Name':Name[0:100], 'Year Span':Year_Span, 'Genre':Genre, 'Run time':Run_time, 'Ratings':Ratings, 'Votes':Votes})
df
# Out:
#                                   Name    Year Span                     Genre  \
# 0       1. Game of Thrones (2011–2019)  (2011–2019)  Action, Adventure, Drama
# 1          2. Stranger Things (2016– )     (2016– )    Drama, Fantasy, Horror
# 2      3. The Walking Dead (2010–2022)  (2010–2022)   Drama, Horror, Thriller
# 3        4. 13 Reasons Why (2017–2020)  (2017–2020)  Drama, Mystery, Thriller
# 4               5. The 100 (2014–2020)  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                                 ...          ...                       ...
# 95        66. The Good Doctor (2017– )  (2013–2017)                     Drama
# 96     67. Jane the Virgin (2014–2019)  (2017–2019)  Adventure, Comedy, Drama
# 97                68. Glee (2009–2015)  (2005–2020)     Crime, Drama, Mystery
# 98             69. South Park (1997– )  (2015–2019)      Comedy, Crime, Drama
# 99  70. Brooklyn Nine-Nine (2013–2021)       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# ...

# %%
driver.close()

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories.

# %%
driver=webdriver.Chrome(r"C:\Users\Hello world\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://archive.ics.uci.edu/")

# %%
# clicking the 'View all dataset'
view_dataset=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
view_dataset.click()

# %%
# Fetching urls for each dataset
dataset_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")    

urls = []     
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
urls
# Out:
# ['https://archive.ics.uci.edu/ml/datasets/Abalone',
#  'https://archive.ics.uci.edu/ml/datasets/Adult',
#  'https://archive.ics.uci.edu/ml/datasets/Annealing',
#  'https://archive.ics.uci.edu/ml/datasets/Anonymous+Microsoft+Web+Data',
#  'https://archive.ics.uci.edu/ml/datasets/Arrhythmia',
#  'https://archive.ics.uci.edu/ml/datasets/Artificial+Characters',
#  'https://archive.ics.uci.edu/ml/datasets/Audiology+%28Original%29',
#  'https://archive.ics.uci.edu/ml/datasets/Audiology+%28Standardized%29',
#  'https://archive.ics.uci.edu/ml/datasets/Auto+MPG',
#  'https://archive.ics.uci.edu/ml/datasets/Automobile',
#  'https://archive.ics.uci.edu/ml/datasets/Badges',
#  'https://archive.ics.uci.edu/ml/datasets/Balance+Scale',
#  'https://archive.ics.uci.edu/ml/datasets/Balloons',
#  'https://archive.ics.uci.edu/ml/datasets/Breast+Cancer',
#  'https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Original%29',
# ...

# %%
#Creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

# %%
for i in urls:
    driver.get(i)
    time.sleep(2)
    
    #Scraping Dataset name
    try: 
        dataset_name = driver.find_element(By.XPATH,"//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    
    
    #Scraping data type
    try:
        data_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    

    #scraping Task
    try:
        task = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    
    
    # Scraping Attribute type
    try:
        attribute_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
        

    # Scraping No of instances
    try:
        instances = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    
    
    # Scraping No of attributes
    try:
        attribute = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
        
      
    # Scraping year
    try:
        year = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')

# %%
df=pd.DataFrame({'Dataset Name':Dataset_name, 'Data type':Data_type, 'Task':Task, 'Attribute Type':Attribute_type, 'No of instances':No_of_instances, 'No of attribute':No_of_attributes, 'Year':Year})
df
# Out:
#                                           Dataset Name  \
# 0                                     Abalone Data Set
# 1                                       Adult Data Set
# 2                                   Annealing Data Set
# 3                Anonymous Microsoft Web Data Data Set
# 4                                  Arrhythmia Data Set
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618             Turkish Music Emotion Dataset Data Set
# 619             Maternal Health Risk Data Set Data Set
# 620                 Room Occupancy Estimation Data Set
# 621  Image Recognition Task Execution Times in Mobi...
#
#                                Data type                 Task  \
# 0                           Multivariate       Classification
# 1                           Multivariate       Classification
# 2                           Multivariate       Classification
# ...

# %%
driver.close()
